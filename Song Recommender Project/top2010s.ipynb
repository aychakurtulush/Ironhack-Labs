# %%
##!conda install -c conda-forge spotipy

# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
# get json of a specific playlist
username = 'Spotify'
playlist_id = '37i9dQZF1DX5Ejj0EkURtP' # get from url of the playplist ('https://open.spotify.com/playlist/37i9dQZF1DX5Ejj0EkURtP')

playlist = sp.user_playlist_tracks(username, playlist_id, market="GB")

# %%
# define a function to extract tracks of a playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# extract tracks from a specific playlist
tracks = get_playlist_tracks(username, playlist_id)

# %%
# extract audio features
list_of_audio_features=[]
for item in range(0,len(tracks)):
    # print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
sp.audio_features(tracks[item]["track"]["id"])[0]
# Out:
# {'danceability': 0.601,
#  'energy': 0.794,
#  'key': 7,
#  'loudness': -5.844,
#  'mode': 0,
#  'speechiness': 0.0671,
#  'acousticness': 0.00987,
#  'instrumentalness': 1.36e-06,
#  'liveness': 0.388,
#  'valence': 0.244,
#  'tempo': 114.066,
#  'type': 'audio_features',
#  'id': '27rdGxbavYJeBphck5MZAF',
#  'uri': 'spotify:track:27rdGxbavYJeBphck5MZAF',
#  'track_href': 'https://api.spotify.com/v1/tracks/27rdGxbavYJeBphck5MZAF',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27rdGxbavYJeBphck5MZAF',
#  'duration_ms': 217467,
#  'time_signature': 4}

# %%
# create a dataframe for audio features
top2010s_feat_df = pd.DataFrame(list_of_audio_features)

# Select some features only

top2010s = top2010s_feat_df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

top2010s
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.735   0.766    -4.485       0.0383       0.02500
# 1           0.758   0.871    -6.408       0.1470       0.00620
# 2           0.532   0.783    -5.697       0.0523       0.00380
# 3           0.669   0.832    -5.721       0.0682       0.01060
# 4           0.654   0.760    -3.669       0.0450       0.07970
# ..            ...     ...       ...          ...           ...
# 145         0.855   0.954    -1.190       0.2640       0.52900
# 146         0.520   0.761    -3.093       0.0853       0.25600
# 147         0.188   0.411    -9.733       0.0484       0.17400
# 148         0.647   0.822    -4.662       0.1830       0.21900
# 149         0.601   0.794    -5.844       0.0671       0.00987
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.001380    0.1080    0.600  127.985  0U10zFw4GlBacOy9VDGfGL
# 1            0.000000    0.0663    0.753  126.994  6bNB5gxFX6Q87DbQWb8OWZ
# 2            0.001200    0.1610    0.643  124.080  0nrRP2bk19rLc0orkWPQk2
# 3            0.000000    0.0968    0.700  113.035  1WkMMavIMc4JZ8cfMmxHkI
# 4            0.000000    0.2990    0.410   99.945  09CtPGIpYB4BrO8qb1RGsF
# ..                ...       ...      ...      ...                     ...
# 145          0.000000    0.2050    0.668  114.635  7Ie9W94M7OjPoZVV216Xus
# 146          0.000005    0.1700    0.286  141.971  7vGuf3Y35N4wmASOKLUVVU
# 147          0.153000    0.0843    0.159  187.376  0NlGoUyOJSuSHmngoibVAs
# 148          0.000000    0.0908    0.962  160.019  60nZcImufyMA1MKQY3dcCH
# 149          0.000001    0.3880    0.244  114.066  27rdGxbavYJeBphck5MZAF
#
#      duration_ms
# 0         215227
# 1         202627
# 2         247427
# 3         237547
# 4         200787
# ..           ...
# 145       248133
# 146       180823
# 147       305747
# 148       232720
# 149       217467
#
# [150 rows x 11 columns]

# %%
list_of_audio_features
# Out:
# [{'danceability': 0.735,
#   'energy': 0.766,
#   'key': 1,
#   'loudness': -4.485,
#   'mode': 1,
#   'speechiness': 0.0383,
#   'acousticness': 0.025,
#   'instrumentalness': 0.00138,
#   'liveness': 0.108,
#   'valence': 0.6,
#   'tempo': 127.985,
#   'type': 'audio_features',
#   'id': '0U10zFw4GlBacOy9VDGfGL',
#   'uri': 'spotify:track:0U10zFw4GlBacOy9VDGfGL',
#   'track_href': 'https://api.spotify.com/v1/tracks/0U10zFw4GlBacOy9VDGfGL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0U10zFw4GlBacOy9VDGfGL',
#   'duration_ms': 215227,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.871,
#   'key': 2,
#   'loudness': -6.408,
#   'mode': 1,
#   'speechiness': 0.147,
#   'acousticness': 0.0062,
#   'instrumentalness': 0,
#   'liveness': 0.0663,
#   'valence': 0.753,
#   'tempo': 126.994,
#   'type': 'audio_features',
#   'id': '6bNB5gxFX6Q87DbQWb8OWZ',
#   'uri': 'spotify:track:6bNB5gxFX6Q87DbQWb8OWZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6bNB5gxFX6Q87DbQWb8OWZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6bNB5gxFX6Q87DbQWb8OWZ',
#   'duration_ms': 202627,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.783,
#   'key': 2,
#   'loudness': -5.697,
#   'mode': 1,
#   'speechiness': 0.0523,
#   'acousticness': 0.0038,
#   'instrumentalness': 0.0012,
#   'liveness': 0.161,
#   'valence': 0.643,
#   'tempo': 124.08,
#   'type': 'audio_features',
#   'id': '0nrRP2bk19rLc0orkWPQk2',
#   'uri': 'spotify:track:0nrRP2bk19rLc0orkWPQk2',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nrRP2bk19rLc0orkWPQk2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nrRP2bk19rLc0orkWPQk2',
#   'duration_ms': 247427,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.832,
#   'key': 0,
#   'loudness': -5.721,
#   'mode': 1,
#   'speechiness': 0.0682,
#   'acousticness': 0.0106,
#   'instrumentalness': 0,
#   'liveness': 0.0968,
#   'valence': 0.7,
#   'tempo': 113.035,
#   'type': 'audio_features',
#   'id': '1WkMMavIMc4JZ8cfMmxHkI',
#   'uri': 'spotify:track:1WkMMavIMc4JZ8cfMmxHkI',
#   'track_href': 'https://api.spotify.com/v1/tracks/1WkMMavIMc4JZ8cfMmxHkI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1WkMMavIMc4JZ8cfMmxHkI',
#   'duration_ms': 237547,
#   'time_signature': 4},
#  {'danceability': 0.654,
#   'energy': 0.76,
#   'key': 0,
#   'loudness': -3.669,
#   'mode': 0,
#   'speechiness': 0.045,
#   'acousticness': 0.0797,
#   'instrumentalness': 0,
#   'liveness': 0.299,
#   'valence': 0.41,
#   'tempo': 99.945,
#   'type': 'audio_features',
#   'id': '09CtPGIpYB4BrO8qb1RGsF',
#   'uri': 'spotify:track:09CtPGIpYB4BrO8qb1RGsF',
#   'track_href': 'https://api.spotify.com/v1/tracks/09CtPGIpYB4BrO8qb1RGsF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09CtPGIpYB4BrO8qb1RGsF',
#   'duration_ms': 200787,
#   'time_signature': 4},
#  {'danceability': 0.262,
#   'energy': 0.606,
#   'key': 8,
#   'loudness': -6.646,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.247,
#   'instrumentalness': 0,
#   'liveness': 0.125,
#   'valence': 0.275,
#   'tempo': 189.857,
#   'type': 'audio_features',
#   'id': '3zHq9ouUJQFQRf3cm1rRLu',
#   'uri': 'spotify:track:3zHq9ouUJQFQRf3cm1rRLu',
#   'track_href': 'https://api.spotify.com/v1/tracks/3zHq9ouUJQFQRf3cm1rRLu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3zHq9ouUJQFQRf3cm1rRLu',
#   'duration_ms': 252534,
#   'time_signature': 4},
#  {'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'type': 'audio_features',
#   'id': '7qiZfU4dY1lWllzX7mPBI3',
#   'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3',
#   'track_href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qiZfU4dY1lWllzX7mPBI3',
#   'duration_ms': 233713,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.658,
#   'key': 2,
#   'loudness': -6.428,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.0215,
#   'instrumentalness': 1.66e-06,
#   'liveness': 0.0939,
#   'valence': 0.219,
#   'tempo': 99.99,
#   'type': 'audio_features',
#   'id': '72jbDTw1piOOj770jWNeaG',
#   'uri': 'spotify:track:72jbDTw1piOOj770jWNeaG',
#   'track_href': 'https://api.spotify.com/v1/tracks/72jbDTw1piOOj770jWNeaG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72jbDTw1piOOj770jWNeaG',
#   'duration_ms': 221507,
#   'time_signature': 4},
#  {'danceability': 0.418,
#   'energy': 0.42,
#   'key': 0,
#   'loudness': -6.444,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.588,
#   'instrumentalness': 6.39e-05,
#   'liveness': 0.11,
#   'valence': 0.184,
#   'tempo': 84.094,
#   'type': 'audio_features',
#   'id': '5Nm9ERjJZ5oyfXZTECKmRt',
#   'uri': 'spotify:track:5Nm9ERjJZ5oyfXZTECKmRt',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Nm9ERjJZ5oyfXZTECKmRt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Nm9ERjJZ5oyfXZTECKmRt',
#   'duration_ms': 172724,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.52,
#   'key': 5,
#   'loudness': -6.136,
#   'mode': 0,
#   'speechiness': 0.0712,
#   'acousticness': 0.124,
#   'instrumentalness': 7.01e-05,
#   'liveness': 0.131,
#   'valence': 0.129,
#   'tempo': 159.801,
#   'type': 'audio_features',
#   'id': '0e7ipj03S05BNilyu5bRzt',
#   'uri': 'spotify:track:0e7ipj03S05BNilyu5bRzt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0e7ipj03S05BNilyu5bRzt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0e7ipj03S05BNilyu5bRzt',
#   'duration_ms': 218147,
#   'time_signature': 4},
#  {'danceability': 0.799,
#   'energy': 0.539,
#   'key': 1,
#   'loudness': -6.351,
#   'mode': 1,
#   'speechiness': 0.0421,
#   'acousticness': 0.199,
#   'instrumentalness': 1.66e-05,
#   'liveness': 0.165,
#   'valence': 0.394,
#   'tempo': 136.948,
#   'type': 'audio_features',
#   'id': '5Z3GHaZ6ec9bsiI5BenrbY',
#   'uri': 'spotify:track:5Z3GHaZ6ec9bsiI5BenrbY',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Z3GHaZ6ec9bsiI5BenrbY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Z3GHaZ6ec9bsiI5BenrbY',
#   'duration_ms': 202547,
#   'time_signature': 4},
#  {'danceability': 0.575,
#   'energy': 0.33,
#   'key': 7,
#   'loudness': -6.557,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.416,
#   'instrumentalness': 0,
#   'liveness': 0.0872,
#   'valence': 0.277,
#   'tempo': 95.801,
#   'type': 'audio_features',
#   'id': '6QfS2wq5sSC1xAJCQsTSlj',
#   'uri': 'spotify:track:6QfS2wq5sSC1xAJCQsTSlj',
#   'track_href': 'https://api.spotify.com/v1/tracks/6QfS2wq5sSC1xAJCQsTSlj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QfS2wq5sSC1xAJCQsTSlj',
#   'duration_ms': 217213,
#   'time_signature': 4},
#  {'danceability': 0.684,
#   'energy': 0.607,
#   'key': 11,
#   'loudness': -8.127,
#   'mode': 0,
#   'speechiness': 0.1,
#   'acousticness': 0.0267,
#   'instrumentalness': 0.000307,
#   'liveness': 0.191,
#   'valence': 0.498,
#   'tempo': 81.001,
#   'type': 'audio_features',
#   'id': '0JXXNGljqupsJaZsgSbMZV',
#   'uri': 'spotify:track:0JXXNGljqupsJaZsgSbMZV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JXXNGljqupsJaZsgSbMZV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JXXNGljqupsJaZsgSbMZV',
#   'duration_ms': 195373,
#   'time_signature': 4},
#  {'danceability': 0.445,
#   'energy': 0.537,
#   'key': 4,
#   'loudness': -8.532,
#   'mode': 0,
#   'speechiness': 0.04,
#   'acousticness': 0.695,
#   'instrumentalness': 1.65e-05,
#   'liveness': 0.0944,
#   'valence': 0.131,
#   'tempo': 122.769,
#   'type': 'audio_features',
#   'id': '3JvKfv6T31zO0ini8iNItO',
#   'uri': 'spotify:track:3JvKfv6T31zO0ini8iNItO',
#   'track_href': 'https://api.spotify.com/v1/tracks/3JvKfv6T31zO0ini8iNItO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JvKfv6T31zO0ini8iNItO',
#   'duration_ms': 244360,
#   'time_signature': 4},
#  {'danceability': 0.679,
#   'energy': 0.587,
#   'key': 7,
#   'loudness': -7.015,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.141,
#   'instrumentalness': 6.35e-06,
#   'liveness': 0.137,
#   'valence': 0.486,
#   'tempo': 186.003,
#   'type': 'audio_features',
#   'id': '7MXVkk9YMctZqd1Srtv4MB',
#   'uri': 'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MXVkk9YMctZqd1Srtv4MB',
#   'duration_ms': 230453,
#   'time_signature': 4},
#  {'danceability': 0.613,
#   'energy': 0.808,
#   'key': 10,
#   'loudness': -2.851,
#   'mode': 1,
#   'speechiness': 0.0346,
#   'acousticness': 0.0426,
#   'instrumentalness': 0.0159,
#   'liveness': 0.102,
#   'valence': 0.38,
#   'tempo': 124.037,
#   'type': 'audio_features',
#   'id': '0cQVqPuHQP4KEwc7ZUQmj6',
#   'uri': 'spotify:track:0cQVqPuHQP4KEwc7ZUQmj6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cQVqPuHQP4KEwc7ZUQmj6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cQVqPuHQP4KEwc7ZUQmj6',
#   'duration_ms': 240427,
#   'time_signature': 4},
#  {'danceability': 0.612,
#   'energy': 0.28,
#   'key': 0,
#   'loudness': -8.648,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.932,
#   'instrumentalness': 0,
#   'liveness': 0.088,
#   'valence': 0.387,
#   'tempo': 72.795,
#   'type': 'audio_features',
#   'id': '0nJW01T7XtvILxQgC5J7Wh',
#   'uri': 'spotify:track:0nJW01T7XtvILxQgC5J7Wh',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nJW01T7XtvILxQgC5J7Wh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nJW01T7XtvILxQgC5J7Wh',
#   'duration_ms': 213827,
#   'time_signature': 4},
#  {'danceability': 0.351,
#   'energy': 0.296,
#   'key': 4,
#   'loudness': -10.109,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.934,
#   'instrumentalness': 0,
#   'liveness': 0.095,
#   'valence': 0.12,
#   'tempo': 115.284,
#   'type': 'audio_features',
#   'id': '0u2P5u6lvoDfwTYjAADbn4',
#   'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0u2P5u6lvoDfwTYjAADbn4',
#   'duration_ms': 200186,
#   'time_signature': 4},
#  {'danceability': 0.69,
#   'energy': 0.521,
#   'key': 10,
#   'loudness': -8.492,
#   'mode': 0,
#   'speechiness': 0.339,
#   'acousticness': 0.324,
#   'instrumentalness': 0,
#   'liveness': 0.0534,
#   'valence': 0.494,
#   'tempo': 100.028,
#   'type': 'audio_features',
#   'id': '68Dni7IE4VyPkTOH9mRWHr',
#   'uri': 'spotify:track:68Dni7IE4VyPkTOH9mRWHr',
#   'track_href': 'https://api.spotify.com/v1/tracks/68Dni7IE4VyPkTOH9mRWHr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/68Dni7IE4VyPkTOH9mRWHr',
#   'duration_ms': 292799,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.816,
#   'key': 0,
#   'loudness': -4.209,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.122,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.557,
#   'tempo': 95.39,
#   'type': 'audio_features',
#   'id': '6UelLqGlWMcVH1E5c4H7lY',
#   'uri': 'spotify:track:6UelLqGlWMcVH1E5c4H7lY',
#   'track_href': 'https://api.spotify.com/v1/tracks/6UelLqGlWMcVH1E5c4H7lY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UelLqGlWMcVH1E5c4H7lY',
#   'duration_ms': 174000,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.448,
#   'key': 8,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0232,
#   'acousticness': 0.163,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.168,
#   'tempo': 95.05,
#   'type': 'audio_features',
#   'id': '0tgVpDi06FyKpA1z0VMD4v',
#   'uri': 'spotify:track:0tgVpDi06FyKpA1z0VMD4v',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tgVpDi06FyKpA1z0VMD4v',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tgVpDi06FyKpA1z0VMD4v',
#   'duration_ms': 263400,
#   'time_signature': 3},
#  {'danceability': 0.548,
#   'energy': 0.532,
#   'key': 5,
#   'loudness': -7.596,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.186,
#   'instrumentalness': 0.000263,
#   'liveness': 0.217,
#   'valence': 0.405,
#   'tempo': 85.03,
#   'type': 'audio_features',
#   'id': '5FVd6KXrgO9B3JPmC8OPst',
#   'uri': 'spotify:track:5FVd6KXrgO9B3JPmC8OPst',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FVd6KXrgO9B3JPmC8OPst',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FVd6KXrgO9B3JPmC8OPst',
#   'duration_ms': 272394,
#   'time_signature': 4},
#  {'danceability': 0.776,
#   'energy': 0.78,
#   'key': 10,
#   'loudness': -4.374,
#   'mode': 0,
#   'speechiness': 0.128,
#   'acousticness': 0.0622,
#   'instrumentalness': 0,
#   'liveness': 0.081,
#   'valence': 0.666,
#   'tempo': 124.949,
#   'type': 'audio_features',
#   'id': '0pqnGHJpmpxLKifKRmU6WP',
#   'uri': 'spotify:track:0pqnGHJpmpxLKifKRmU6WP',
#   'track_href': 'https://api.spotify.com/v1/tracks/0pqnGHJpmpxLKifKRmU6WP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0pqnGHJpmpxLKifKRmU6WP',
#   'duration_ms': 204347,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.593,
#   'key': 1,
#   'loudness': -4.954,
#   'mode': 1,
#   'speechiness': 0.0356,
#   'acousticness': 0.17,
#   'instrumentalness': 0,
#   'liveness': 0.307,
#   'valence': 0.175,
#   'tempo': 134.17,
#   'type': 'audio_features',
#   'id': '09mEdoA6zrmBPgTEN5qXmN',
#   'uri': 'spotify:track:09mEdoA6zrmBPgTEN5qXmN',
#   'track_href': 'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09mEdoA6zrmBPgTEN5qXmN',
#   'duration_ms': 228373,
#   'time_signature': 3},
#  {'danceability': 0.501,
#   'energy': 0.405,
#   'key': 1,
#   'loudness': -5.679,
#   'mode': 1,
#   'speechiness': 0.0319,
#   'acousticness': 0.751,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.446,
#   'tempo': 109.891,
#   'type': 'audio_features',
#   'id': '7qEHsqek33rTcFNT9PFqLf',
#   'uri': 'spotify:track:7qEHsqek33rTcFNT9PFqLf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7qEHsqek33rTcFNT9PFqLf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qEHsqek33rTcFNT9PFqLf',
#   'duration_ms': 182161,
#   'time_signature': 4},
#  {'danceability': 0.672,
#   'energy': 0.52,
#   'key': 8,
#   'loudness': -7.747,
#   'mode': 1,
#   'speechiness': 0.0353,
#   'acousticness': 0.859,
#   'instrumentalness': 0,
#   'liveness': 0.115,
#   'valence': 0.37,
#   'tempo': 120.001,
#   'type': 'audio_features',
#   'id': '5O2P9iiztwhomNh8xkR9lJ',
#   'uri': 'spotify:track:5O2P9iiztwhomNh8xkR9lJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5O2P9iiztwhomNh8xkR9lJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5O2P9iiztwhomNh8xkR9lJ',
#   'duration_ms': 226600,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.862,
#   'key': 9,
#   'loudness': -3.24,
#   'mode': 0,
#   'speechiness': 0.11,
#   'acousticness': 0.037,
#   'instrumentalness': 2.19e-05,
#   'liveness': 0.0814,
#   'valence': 0.592,
#   'tempo': 123.994,
#   'type': 'audio_features',
#   'id': '7ef4DlsgrMEH11cDZd32M6',
#   'uri': 'spotify:track:7ef4DlsgrMEH11cDZd32M6',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ef4DlsgrMEH11cDZd32M6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ef4DlsgrMEH11cDZd32M6',
#   'duration_ms': 214847,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.646,
#   'key': 7,
#   'loudness': -5.795,
#   'mode': 1,
#   'speechiness': 0.317,
#   'acousticness': 0.152,
#   'instrumentalness': 1.85e-05,
#   'liveness': 0.108,
#   'valence': 0.429,
#   'tempo': 176.089,
#   'type': 'audio_features',
#   'id': '0fea68AdmYNygeTGI4RC18',
#   'uri': 'spotify:track:0fea68AdmYNygeTGI4RC18',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fea68AdmYNygeTGI4RC18',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fea68AdmYNygeTGI4RC18',
#   'duration_ms': 242573,
#   'time_signature': 4},
#  {'danceability': 0.726,
#   'energy': 0.698,
#   'key': 5,
#   'loudness': -4.165,
#   'mode': 1,
#   'speechiness': 0.0431,
#   'acousticness': 0.049,
#   'instrumentalness': 0,
#   'liveness': 0.309,
#   'valence': 0.867,
#   'tempo': 143.994,
#   'type': 'audio_features',
#   'id': '3w3y8KPTfNeOKPiqUTakBh',
#   'uri': 'spotify:track:3w3y8KPTfNeOKPiqUTakBh',
#   'track_href': 'https://api.spotify.com/v1/tracks/3w3y8KPTfNeOKPiqUTakBh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3w3y8KPTfNeOKPiqUTakBh',
#   'duration_ms': 233478,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.631,
#   'key': 2,
#   'loudness': -6.478,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.0483,
#   'instrumentalness': 1.13e-05,
#   'liveness': 0.104,
#   'valence': 0.8,
#   'tempo': 92.004,
#   'type': 'audio_features',
#   'id': '086myS9r57YsLbJpU0TgK9',
#   'uri': 'spotify:track:086myS9r57YsLbJpU0TgK9',
#   'track_href': 'https://api.spotify.com/v1/tracks/086myS9r57YsLbJpU0TgK9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/086myS9r57YsLbJpU0TgK9',
#   'duration_ms': 161124,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.485,
#   'key': 5,
#   'loudness': -5.795,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.529,
#   'instrumentalness': 2.04e-05,
#   'liveness': 0.0766,
#   'valence': 0.493,
#   'tempo': 82.001,
#   'type': 'audio_features',
#   'id': '7795WJLVKJoAyVoOtCWqXN',
#   'uri': 'spotify:track:7795WJLVKJoAyVoOtCWqXN',
#   'track_href': 'https://api.spotify.com/v1/tracks/7795WJLVKJoAyVoOtCWqXN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7795WJLVKJoAyVoOtCWqXN',
#   'duration_ms': 239317,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.637,
#   'key': 4,
#   'loudness': -4.83,
#   'mode': 0,
#   'speechiness': 0.0471,
#   'acousticness': 0.0717,
#   'instrumentalness': 1.08e-05,
#   'liveness': 0.0789,
#   'valence': 0.378,
#   'tempo': 172.006,
#   'type': 'audio_features',
#   'id': '5oO3drDxtziYU2H1X23ZIp',
#   'uri': 'spotify:track:5oO3drDxtziYU2H1X23ZIp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5oO3drDxtziYU2H1X23ZIp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5oO3drDxtziYU2H1X23ZIp',
#   'duration_ms': 224000,
#   'time_signature': 3},
#  {'danceability': 0.585,
#   'energy': 0.564,
#   'key': 0,
#   'loudness': -7.063,
#   'mode': 0,
#   'speechiness': 0.0515,
#   'acousticness': 0.0671,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.137,
#   'tempo': 113.003,
#   'type': 'audio_features',
#   'id': '7fBv7CLKzipRk6EC6TWHOB',
#   'uri': 'spotify:track:7fBv7CLKzipRk6EC6TWHOB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7fBv7CLKzipRk6EC6TWHOB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7fBv7CLKzipRk6EC6TWHOB',
#   'duration_ms': 242253,
#   'time_signature': 4},
#  {'danceability': 0.866,
#   'energy': 0.813,
#   'key': 11,
#   'loudness': -4.063,
#   'mode': 0,
#   'speechiness': 0.0554,
#   'acousticness': 0.38,
#   'instrumentalness': 0,
#   'liveness': 0.0779,
#   'valence': 0.969,
#   'tempo': 121.998,
#   'type': 'audio_features',
#   'id': '7JJmb5XwzOO8jgpou264Ml',
#   'uri': 'spotify:track:7JJmb5XwzOO8jgpou264Ml',
#   'track_href': 'https://api.spotify.com/v1/tracks/7JJmb5XwzOO8jgpou264Ml',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7JJmb5XwzOO8jgpou264Ml',
#   'duration_ms': 199440,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.762,
#   'key': 0,
#   'loudness': -3.497,
#   'mode': 1,
#   'speechiness': 0.0395,
#   'acousticness': 0.192,
#   'instrumentalness': 0.00244,
#   'liveness': 0.0863,
#   'valence': 0.553,
#   'tempo': 120.042,
#   'type': 'audio_features',
#   'id': '21jGcNKet2qwijlDFuPiPb',
#   'uri': 'spotify:track:21jGcNKet2qwijlDFuPiPb',
#   'track_href': 'https://api.spotify.com/v1/tracks/21jGcNKet2qwijlDFuPiPb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21jGcNKet2qwijlDFuPiPb',
#   'duration_ms': 215280,
#   'time_signature': 4},
#  {'danceability': 0.527,
#   'energy': 0.835,
#   'key': 6,
#   'loudness': -5.298,
#   'mode': 1,
#   'speechiness': 0.0433,
#   'acousticness': 0.0166,
#   'instrumentalness': 0,
#   'liveness': 0.249,
#   'valence': 0.654,
#   'tempo': 125.983,
#   'type': 'audio_features',
#   'id': '0ct6r3EGTcMLPtrXHDvVjc',
#   'uri': 'spotify:track:0ct6r3EGTcMLPtrXHDvVjc',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ct6r3EGTcMLPtrXHDvVjc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ct6r3EGTcMLPtrXHDvVjc',
#   'duration_ms': 176658,
#   'time_signature': 4},
#  {'danceability': 0.545,
#   'energy': 0.545,
#   'key': 9,
#   'loudness': -7.362,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.667,
#   'instrumentalness': 5.48e-05,
#   'liveness': 0.417,
#   'valence': 0.549,
#   'tempo': 159.94,
#   'type': 'audio_features',
#   'id': '3xKsf9qdS1CyvXSMEid6g8',
#   'uri': 'spotify:track:3xKsf9qdS1CyvXSMEid6g8',
#   'track_href': 'https://api.spotify.com/v1/tracks/3xKsf9qdS1CyvXSMEid6g8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3xKsf9qdS1CyvXSMEid6g8',
#   'duration_ms': 184516,
#   'time_signature': 3},
#  {'danceability': 0.422,
#   'energy': 0.264,
#   'key': 8,
#   'loudness': -7.064,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.922,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.331,
#   'tempo': 119.93,
#   'type': 'audio_features',
#   'id': '3U4isOIWM3VvDubwSI3y7a',
#   'uri': 'spotify:track:3U4isOIWM3VvDubwSI3y7a',
#   'track_href': 'https://api.spotify.com/v1/tracks/3U4isOIWM3VvDubwSI3y7a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3U4isOIWM3VvDubwSI3y7a',
#   'duration_ms': 269560,
#   'time_signature': 4},
#  {'danceability': 0.588,
#   'energy': 0.521,
#   'key': 10,
#   'loudness': -9.461,
#   'mode': 1,
#   'speechiness': 0.0329,
#   'acousticness': 0.0678,
#   'instrumentalness': 0.149,
#   'liveness': 0.123,
#   'valence': 0.337,
#   'tempo': 85.012,
#   'type': 'audio_features',
#   'id': '5E30LdtzQTGqRvNd7l6kG5',
#   'uri': 'spotify:track:5E30LdtzQTGqRvNd7l6kG5',
#   'track_href': 'https://api.spotify.com/v1/tracks/5E30LdtzQTGqRvNd7l6kG5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5E30LdtzQTGqRvNd7l6kG5',
#   'duration_ms': 260173,
#   'time_signature': 4},
#  {'danceability': 0.792,
#   'energy': 0.625,
#   'key': 1,
#   'loudness': -5.609,
#   'mode': 1,
#   'speechiness': 0.0536,
#   'acousticness': 0.00776,
#   'instrumentalness': 0.0018,
#   'liveness': 0.329,
#   'valence': 0.37,
#   'tempo': 103.967,
#   'type': 'audio_features',
#   'id': '1zi7xx7UVEFkmKfv06H8x0',
#   'uri': 'spotify:track:1zi7xx7UVEFkmKfv06H8x0',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zi7xx7UVEFkmKfv06H8x0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zi7xx7UVEFkmKfv06H8x0',
#   'duration_ms': 173987,
#   'time_signature': 4},
#  {'danceability': 0.775,
#   'energy': 0.327,
#   'key': 11,
#   'loudness': -7.241,
#   'mode': 1,
#   'speechiness': 0.0557,
#   'acousticness': 0.841,
#   'instrumentalness': 0,
#   'liveness': 0.0821,
#   'valence': 0.595,
#   'tempo': 91.05,
#   'type': 'audio_features',
#   'id': '4cktbXiXOapiLBMprHFErI',
#   'uri': 'spotify:track:4cktbXiXOapiLBMprHFErI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4cktbXiXOapiLBMprHFErI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4cktbXiXOapiLBMprHFErI',
#   'duration_ms': 189486,
#   'time_signature': 4},
#  {'danceability': 0.511,
#   'energy': 0.566,
#   'key': 6,
#   'loudness': -7.23,
#   'mode': 0,
#   'speechiness': 0.2,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.34,
#   'valence': 0.218,
#   'tempo': 83.903,
#   'type': 'audio_features',
#   'id': '285pBltuF7vW8TeWk8hdRR',
#   'uri': 'spotify:track:285pBltuF7vW8TeWk8hdRR',
#   'track_href': 'https://api.spotify.com/v1/tracks/285pBltuF7vW8TeWk8hdRR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/285pBltuF7vW8TeWk8hdRR',
#   'duration_ms': 239836,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.379,
#   'key': 4,
#   'loudness': -10.48,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'acousticness': 0.607,
#   'instrumentalness': 0.000464,
#   'liveness': 0.0986,
#   'valence': 0.201,
#   'tempo': 107.989,
#   'type': 'audio_features',
#   'id': '1HNkqx9Ahdgi1Ixy2xkKkL',
#   'uri': 'spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HNkqx9Ahdgi1Ixy2xkKkL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HNkqx9Ahdgi1Ixy2xkKkL',
#   'duration_ms': 258987,
#   'time_signature': 4},
#  {'danceability': 0.676,
#   'energy': 0.771,
#   'key': 8,
#   'loudness': -3.675,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.0237,
#   'instrumentalness': 7e-06,
#   'liveness': 0.102,
#   'valence': 0.569,
#   'tempo': 99.048,
#   'type': 'audio_features',
#   'id': '3jjujdWJ72nww5eGnfs2E7',
#   'uri': 'spotify:track:3jjujdWJ72nww5eGnfs2E7',
#   'track_href': 'https://api.spotify.com/v1/tracks/3jjujdWJ72nww5eGnfs2E7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3jjujdWJ72nww5eGnfs2E7',
#   'duration_ms': 207133,
#   'time_signature': 4},
#  {'danceability': 0.714,
#   'energy': 0.8,
#   'key': 11,
#   'loudness': -4.808,
#   'mode': 0,
#   'speechiness': 0.0504,
#   'acousticness': 0.127,
#   'instrumentalness': 0,
#   'liveness': 0.359,
#   'valence': 0.589,
#   'tempo': 134.002,
#   'type': 'audio_features',
#   'id': '3Wrjm47oTz2sjIgck11l5e',
#   'uri': 'spotify:track:3Wrjm47oTz2sjIgck11l5e',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Wrjm47oTz2sjIgck11l5e',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Wrjm47oTz2sjIgck11l5e',
#   'duration_ms': 211560,
#   'time_signature': 4},
#  {'danceability': 0.698,
#   'energy': 0.633,
#   'key': 8,
#   'loudness': -4.946,
#   'mode': 1,
#   'speechiness': 0.0597,
#   'acousticness': 0.0605,
#   'instrumentalness': 0.000194,
#   'liveness': 0.0926,
#   'valence': 0.552,
#   'tempo': 96.924,
#   'type': 'audio_features',
#   'id': '3GCdLUSnKSMJhs4Tj6CV3s',
#   'uri': 'spotify:track:3GCdLUSnKSMJhs4Tj6CV3s',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GCdLUSnKSMJhs4Tj6CV3s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GCdLUSnKSMJhs4Tj6CV3s',
#   'duration_ms': 232187,
#   'time_signature': 4},
#  {'danceability': 0.658,
#   'energy': 0.671,
#   'key': 2,
#   'loudness': -12.21,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.0933,
#   'instrumentalness': 0.000927,
#   'liveness': 0.115,
#   'valence': 0.166,
#   'tempo': 100.966,
#   'type': 'audio_features',
#   'id': '2vXKRlJBXyOcvZYTdNeckS',
#   'uri': 'spotify:track:2vXKRlJBXyOcvZYTdNeckS',
#   'track_href': 'https://api.spotify.com/v1/tracks/2vXKRlJBXyOcvZYTdNeckS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vXKRlJBXyOcvZYTdNeckS',
#   'duration_ms': 202093,
#   'time_signature': 4},
#  {'danceability': 0.444,
#   'energy': 0.819,
#   'key': 10,
#   'loudness': -4.078,
#   'mode': 0,
#   'speechiness': 0.341,
#   'acousticness': 0.106,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.747,
#   'tempo': 82.695,
#   'type': 'audio_features',
#   'id': '3QGsuHI8jO1Rx4JWLUh9jd',
#   'uri': 'spotify:track:3QGsuHI8jO1Rx4JWLUh9jd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QGsuHI8jO1Rx4JWLUh9jd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QGsuHI8jO1Rx4JWLUh9jd',
#   'duration_ms': 187973,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.557,
#   'key': 1,
#   'loudness': -5.714,
#   'mode': 0,
#   'speechiness': 0.0318,
#   'acousticness': 0.74,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.483,
#   'tempo': 150.073,
#   'type': 'audio_features',
#   'id': '2qxmye6gAegTMjLKEBoR3d',
#   'uri': 'spotify:track:2qxmye6gAegTMjLKEBoR3d',
#   'track_href': 'https://api.spotify.com/v1/tracks/2qxmye6gAegTMjLKEBoR3d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2qxmye6gAegTMjLKEBoR3d',
#   'duration_ms': 169354,
#   'time_signature': 4},
#  {'danceability': 0.605,
#   'energy': 0.822,
#   'key': 0,
#   'loudness': -4.833,
#   'mode': 1,
#   'speechiness': 0.0438,
#   'acousticness': 0.00671,
#   'instrumentalness': 0.134,
#   'liveness': 0.147,
#   'valence': 0.288,
#   'tempo': 167.997,
#   'type': 'audio_features',
#   'id': '1zB4vmk8tFRmM9UULNzbLB',
#   'uri': 'spotify:track:1zB4vmk8tFRmM9UULNzbLB',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zB4vmk8tFRmM9UULNzbLB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zB4vmk8tFRmM9UULNzbLB',
#   'duration_ms': 187147,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.317,
#   'key': 1,
#   'loudness': -10.732,
#   'mode': 0,
#   'speechiness': 0.334,
#   'acousticness': 0.592,
#   'instrumentalness': 0,
#   'liveness': 0.0881,
#   'valence': 0.327,
#   'tempo': 140.048,
#   'type': 'audio_features',
#   'id': '6ocbgoVGwYJhOv1GgI9NsF',
#   'uri': 'spotify:track:6ocbgoVGwYJhOv1GgI9NsF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ocbgoVGwYJhOv1GgI9NsF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ocbgoVGwYJhOv1GgI9NsF',
#   'duration_ms': 178627,
#   'time_signature': 4},
#  {'danceability': 0.495,
#   'energy': 0.722,
#   'key': 6,
#   'loudness': -8.108,
#   'mode': 0,
#   'speechiness': 0.357,
#   'acousticness': 0.0697,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.539,
#   'tempo': 175.627,
#   'type': 'audio_features',
#   'id': '4tqcoej1zPvwePZCzuAjJd',
#   'uri': 'spotify:track:4tqcoej1zPvwePZCzuAjJd',
#   'track_href': 'https://api.spotify.com/v1/tracks/4tqcoej1zPvwePZCzuAjJd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4tqcoej1zPvwePZCzuAjJd',
#   'duration_ms': 239267,
#   'time_signature': 4},
#  {'danceability': 0.734,
#   'energy': 0.637,
#   'key': 4,
#   'loudness': -5.677,
#   'mode': 0,
#   'speechiness': 0.141,
#   'acousticness': 0.0462,
#   'instrumentalness': 2.29e-05,
#   'liveness': 0.0602,
#   'valence': 0.648,
#   'tempo': 169.977,
#   'type': 'audio_features',
#   'id': '3CRDbSIZ4r5MsZ0YwxuEkn',
#   'uri': 'spotify:track:3CRDbSIZ4r5MsZ0YwxuEkn',
#   'track_href': 'https://api.spotify.com/v1/tracks/3CRDbSIZ4r5MsZ0YwxuEkn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3CRDbSIZ4r5MsZ0YwxuEkn',
#   'duration_ms': 202333,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.524,
#   'key': 8,
#   'loudness': -5.599,
#   'mode': 1,
#   'speechiness': 0.0338,
#   'acousticness': 0.414,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.661,
#   'tempo': 95.01,
#   'type': 'audio_features',
#   'id': '7BKLCZ1jbUBVqRi2FVlTVw',
#   'uri': 'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BKLCZ1jbUBVqRi2FVlTVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BKLCZ1jbUBVqRi2FVlTVw',
#   'duration_ms': 244960,
#   'time_signature': 4},
#  {'danceability': 0.359,
#   'energy': 0.543,
#   'key': 7,
#   'loudness': -7.582,
#   'mode': 1,
#   'speechiness': 0.0919,
#   'acousticness': 0.492,
#   'instrumentalness': 1.58e-05,
#   'liveness': 0.118,
#   'valence': 0.453,
#   'tempo': 68.534,
#   'type': 'audio_features',
#   'id': '1dGr1c8CrMLDpV6mPbImSI',
#   'uri': 'spotify:track:1dGr1c8CrMLDpV6mPbImSI',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dGr1c8CrMLDpV6mPbImSI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dGr1c8CrMLDpV6mPbImSI',
#   'duration_ms': 221307,
#   'time_signature': 4},
#  {'danceability': 0.897,
#   'energy': 0.662,
#   'key': 1,
#   'loudness': -6.903,
#   'mode': 0,
#   'speechiness': 0.292,
#   'acousticness': 0.0852,
#   'instrumentalness': 0,
#   'liveness': 0.534,
#   'valence': 0.389,
#   'tempo': 112.511,
#   'type': 'audio_features',
#   'id': '78QR3Wp35dqAhFEc2qAGjE',
#   'uri': 'spotify:track:78QR3Wp35dqAhFEc2qAGjE',
#   'track_href': 'https://api.spotify.com/v1/tracks/78QR3Wp35dqAhFEc2qAGjE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78QR3Wp35dqAhFEc2qAGjE',
#   'duration_ms': 145543,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.353,
#   'key': 1,
#   'loudness': -10.614,
#   'mode': 1,
#   'speechiness': 0.0983,
#   'acousticness': 0.174,
#   'instrumentalness': 0.00662,
#   'liveness': 0.118,
#   'valence': 0.598,
#   'tempo': 160.111,
#   'type': 'audio_features',
#   'id': '0WtDGnWL2KrMCk0mI1Gpwz',
#   'uri': 'spotify:track:0WtDGnWL2KrMCk0mI1Gpwz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WtDGnWL2KrMCk0mI1Gpwz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WtDGnWL2KrMCk0mI1Gpwz',
#   'duration_ms': 326933,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.225,
#   'key': 6,
#   'loudness': -14.454,
#   'mode': 0,
#   'speechiness': 0.0994,
#   'acousticness': 0.902,
#   'instrumentalness': 0.657,
#   'liveness': 0.106,
#   'valence': 0.243,
#   'tempo': 120.006,
#   'type': 'audio_features',
#   'id': '3ZCTVFBt2Brf31RLEnCkWJ',
#   'uri': 'spotify:track:3ZCTVFBt2Brf31RLEnCkWJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZCTVFBt2Brf31RLEnCkWJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZCTVFBt2Brf31RLEnCkWJ',
#   'duration_ms': 245426,
#   'time_signature': 4},
#  {'danceability': 0.789,
#   'energy': 0.858,
#   'key': 1,
#   'loudness': -5.542,
#   'mode': 1,
#   'speechiness': 0.311,
#   'acousticness': 0.127,
#   'instrumentalness': 0,
#   'liveness': 0.349,
#   'valence': 0.775,
#   'tempo': 140.022,
#   'type': 'audio_features',
#   'id': '4Li2WHPkuyCdtmokzW2007',
#   'uri': 'spotify:track:4Li2WHPkuyCdtmokzW2007',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Li2WHPkuyCdtmokzW2007',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Li2WHPkuyCdtmokzW2007',
#   'duration_ms': 219333,
#   'time_signature': 4},
#  {'danceability': 0.853,
#   'energy': 0.56,
#   'key': 1,
#   'loudness': -4.961,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.013,
#   'instrumentalness': 0,
#   'liveness': 0.0944,
#   'valence': 0.86,
#   'tempo': 134.066,
#   'type': 'audio_features',
#   'id': '0KKkJNfGyhkQ5aFogxQAPU',
#   'uri': 'spotify:track:0KKkJNfGyhkQ5aFogxQAPU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0KKkJNfGyhkQ5aFogxQAPU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KKkJNfGyhkQ5aFogxQAPU',
#   'duration_ms': 206693,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.74,
#   'key': 4,
#   'loudness': -4.083,
#   'mode': 1,
#   'speechiness': 0.0284,
#   'acousticness': 0.0115,
#   'instrumentalness': 0.00678,
#   'liveness': 0.167,
#   'valence': 0.785,
#   'tempo': 116.879,
#   'type': 'audio_features',
#   'id': '6K4t31amVTZDgR3sKmwUJJ',
#   'uri': 'spotify:track:6K4t31amVTZDgR3sKmwUJJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6K4t31amVTZDgR3sKmwUJJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6K4t31amVTZDgR3sKmwUJJ',
#   'duration_ms': 216320,
#   'time_signature': 4},
#  {'danceability': 0.913,
#   'energy': 0.603,
#   'key': 8,
#   'loudness': -4.892,
#   'mode': 1,
#   'speechiness': 0.226,
#   'acousticness': 0.0272,
#   'instrumentalness': 0.000503,
#   'liveness': 0.167,
#   'valence': 0.497,
#   'tempo': 123.061,
#   'type': 'audio_features',
#   'id': '3GZD6HmiNUhxXYf8Gch723',
#   'uri': 'spotify:track:3GZD6HmiNUhxXYf8Gch723',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GZD6HmiNUhxXYf8Gch723',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GZD6HmiNUhxXYf8Gch723',
#   'duration_ms': 234093,
#   'time_signature': 4},
#  {'danceability': 0.515,
#   'energy': 0.479,
#   'key': 3,
#   'loudness': -7.458,
#   'mode': 1,
#   'speechiness': 0.0261,
#   'acousticness': 0.544,
#   'instrumentalness': 0.00598,
#   'liveness': 0.191,
#   'valence': 0.284,
#   'tempo': 88.964,
#   'type': 'audio_features',
#   'id': '0rKtyWc8bvkriBthvHKY8d',
#   'uri': 'spotify:track:0rKtyWc8bvkriBthvHKY8d',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rKtyWc8bvkriBthvHKY8d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rKtyWc8bvkriBthvHKY8d',
#   'duration_ms': 209274,
#   'time_signature': 4},
#  {'danceability': 0.749,
#   'energy': 0.925,
#   'key': 10,
#   'loudness': -5.034,
#   'mode': 1,
#   'speechiness': 0.227,
#   'acousticness': 0.241,
#   'instrumentalness': 0,
#   'liveness': 0.52,
#   'valence': 0.641,
#   'tempo': 86.989,
#   'type': 'audio_features',
#   'id': '15JINEqzVMv3SvJTAXAKED',
#   'uri': 'spotify:track:15JINEqzVMv3SvJTAXAKED',
#   'track_href': 'https://api.spotify.com/v1/tracks/15JINEqzVMv3SvJTAXAKED',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15JINEqzVMv3SvJTAXAKED',
#   'duration_ms': 263373,
#   'time_signature': 4},
#  {'danceability': 0.726,
#   'energy': 0.787,
#   'key': 4,
#   'loudness': -2.494,
#   'mode': 1,
#   'speechiness': 0.0737,
#   'acousticness': 0.009,
#   'instrumentalness': 0,
#   'liveness': 0.0596,
#   'valence': 0.888,
#   'tempo': 124.99,
#   'type': 'audio_features',
#   'id': '4cluDES4hQEUhmXj6TXkSo',
#   'uri': 'spotify:track:4cluDES4hQEUhmXj6TXkSo',
#   'track_href': 'https://api.spotify.com/v1/tracks/4cluDES4hQEUhmXj6TXkSo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4cluDES4hQEUhmXj6TXkSo',
#   'duration_ms': 199987,
#   'time_signature': 4},
#  {'danceability': 0.841,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -3.37,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.0847,
#   'instrumentalness': 0,
#   'liveness': 0.149,
#   'valence': 0.43,
#   'tempo': 130.049,
#   'type': 'audio_features',
#   'id': '6gBFPUFcJLzWGx4lenP6h2',
#   'uri': 'spotify:track:6gBFPUFcJLzWGx4lenP6h2',
#   'track_href': 'https://api.spotify.com/v1/tracks/6gBFPUFcJLzWGx4lenP6h2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gBFPUFcJLzWGx4lenP6h2',
#   'duration_ms': 243837,
#   'time_signature': 4},
#  {'danceability': 0.516,
#   'energy': 0.595,
#   'key': 5,
#   'loudness': -4.63,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.0275,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.222,
#   'tempo': 119.972,
#   'type': 'audio_features',
#   'id': '5Ohxk2dO5COHF1krpoPigN',
#   'uri': 'spotify:track:5Ohxk2dO5COHF1krpoPigN',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Ohxk2dO5COHF1krpoPigN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Ohxk2dO5COHF1krpoPigN',
#   'duration_ms': 340707,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.378,
#   'key': 4,
#   'loudness': -9.828,
#   'mode': 1,
#   'speechiness': 0.438,
#   'acousticness': 0.835,
#   'instrumentalness': 0,
#   'liveness': 0.28,
#   'valence': 0.515,
#   'tempo': 100.418,
#   'type': 'audio_features',
#   'id': '50kpGaPAhYJ3sGmk6vplg0',
#   'uri': 'spotify:track:50kpGaPAhYJ3sGmk6vplg0',
#   'track_href': 'https://api.spotify.com/v1/tracks/50kpGaPAhYJ3sGmk6vplg0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50kpGaPAhYJ3sGmk6vplg0',
#   'duration_ms': 233720,
#   'time_signature': 4},
#  {'danceability': 0.545,
#   'energy': 0.675,
#   'key': 6,
#   'loudness': -6.474,
#   'mode': 1,
#   'speechiness': 0.0279,
#   'acousticness': 0.00617,
#   'instrumentalness': 0.00197,
#   'liveness': 0.209,
#   'valence': 0.162,
#   'tempo': 124.97,
#   'type': 'audio_features',
#   'id': '0FDzzruyVECATHXKHFs9eJ',
#   'uri': 'spotify:track:0FDzzruyVECATHXKHFs9eJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0FDzzruyVECATHXKHFs9eJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FDzzruyVECATHXKHFs9eJ',
#   'duration_ms': 267867,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.673,
#   'key': 11,
#   'loudness': -6.941,
#   'mode': 0,
#   'speechiness': 0.0444,
#   'acousticness': 0.148,
#   'instrumentalness': 5.29e-05,
#   'liveness': 0.304,
#   'valence': 0.494,
#   'tempo': 121.963,
#   'type': 'audio_features',
#   'id': '1SOClUWhOi8vHZYMz3GluK',
#   'uri': 'spotify:track:1SOClUWhOi8vHZYMz3GluK',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SOClUWhOi8vHZYMz3GluK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SOClUWhOi8vHZYMz3GluK',
#   'duration_ms': 237720,
#   'time_signature': 4},
#  {'danceability': 0.872,
#   'energy': 0.391,
#   'key': 0,
#   'loudness': -9.144,
#   'mode': 0,
#   'speechiness': 0.242,
#   'acousticness': 0.469,
#   'instrumentalness': 4.13e-06,
#   'liveness': 0.297,
#   'valence': 0.437,
#   'tempo': 134.021,
#   'type': 'audio_features',
#   'id': '7m9OqQk4RVRkw9JJdeAw96',
#   'uri': 'spotify:track:7m9OqQk4RVRkw9JJdeAw96',
#   'track_href': 'https://api.spotify.com/v1/tracks/7m9OqQk4RVRkw9JJdeAw96',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7m9OqQk4RVRkw9JJdeAw96',
#   'duration_ms': 119133,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.713,
#   'key': 1,
#   'loudness': -5.522,
#   'mode': 0,
#   'speechiness': 0.0303,
#   'acousticness': 0.0205,
#   'instrumentalness': 0,
#   'liveness': 0.059,
#   'valence': 0.879,
#   'tempo': 120.032,
#   'type': 'audio_features',
#   'id': '4gbVRS8gloEluzf0GzDOFc',
#   'uri': 'spotify:track:4gbVRS8gloEluzf0GzDOFc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4gbVRS8gloEluzf0GzDOFc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4gbVRS8gloEluzf0GzDOFc',
#   'duration_ms': 189960,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.318,
#   'key': 7,
#   'loudness': -12.695,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.896,
#   'instrumentalness': 0.00239,
#   'liveness': 0.0795,
#   'valence': 0.112,
#   'tempo': 119.959,
#   'type': 'audio_features',
#   'id': '04sN26COy28wTXYj3dMoiZ',
#   'uri': 'spotify:track:04sN26COy28wTXYj3dMoiZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/04sN26COy28wTXYj3dMoiZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/04sN26COy28wTXYj3dMoiZ',
#   'duration_ms': 180933,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.449,
#   'key': 7,
#   'loudness': -9.211,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0332,
#   'instrumentalness': 8.29e-05,
#   'liveness': 0.552,
#   'valence': 0.357,
#   'tempo': 77.169,
#   'type': 'audio_features',
#   'id': '6DCZcSspjsKoFjzjrWoCdn',
#   'uri': 'spotify:track:6DCZcSspjsKoFjzjrWoCdn',
#   'track_href': 'https://api.spotify.com/v1/tracks/6DCZcSspjsKoFjzjrWoCdn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6DCZcSspjsKoFjzjrWoCdn',
#   'duration_ms': 198973,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.575,
#   'key': 3,
#   'loudness': -4.858,
#   'mode': 1,
#   'speechiness': 0.0573,
#   'acousticness': 0.604,
#   'instrumentalness': 0,
#   'liveness': 0.0885,
#   'valence': 0.183,
#   'tempo': 111.881,
#   'type': 'audio_features',
#   'id': '2gMXnyrvIjhVBUZwvLZDMP',
#   'uri': 'spotify:track:2gMXnyrvIjhVBUZwvLZDMP',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gMXnyrvIjhVBUZwvLZDMP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gMXnyrvIjhVBUZwvLZDMP',
#   'duration_ms': 215107,
#   'time_signature': 4},
#  {'danceability': 0.765,
#   'energy': 0.356,
#   'key': 11,
#   'loudness': -5.556,
#   'mode': 0,
#   'speechiness': 0.195,
#   'acousticness': 0.223,
#   'instrumentalness': 0,
#   'liveness': 0.0963,
#   'valence': 0.189,
#   'tempo': 96.991,
#   'type': 'audio_features',
#   'id': '3pXF1nA74528Edde4of9CC',
#   'uri': 'spotify:track:3pXF1nA74528Edde4of9CC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pXF1nA74528Edde4of9CC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pXF1nA74528Edde4of9CC',
#   'duration_ms': 198293,
#   'time_signature': 4},
#  {'danceability': 0.53,
#   'energy': 0.422,
#   'key': 5,
#   'loudness': -6.262,
#   'mode': 1,
#   'speechiness': 0.0342,
#   'acousticness': 0.407,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.349,
#   'tempo': 119.964,
#   'type': 'audio_features',
#   'id': '2vwlzO0Qp8kfEtzTsCXfyE',
#   'uri': 'spotify:track:2vwlzO0Qp8kfEtzTsCXfyE',
#   'track_href': 'https://api.spotify.com/v1/tracks/2vwlzO0Qp8kfEtzTsCXfyE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vwlzO0Qp8kfEtzTsCXfyE',
#   'duration_ms': 221360,
#   'time_signature': 4},
#  {'danceability': 0.781,
#   'energy': 0.445,
#   'key': 2,
#   'loudness': -6.061,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.474,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.591,
#   'tempo': 78.998,
#   'type': 'audio_features',
#   'id': '34gCuhDGsG4bRPIf9bb02f',
#   'uri': 'spotify:track:34gCuhDGsG4bRPIf9bb02f',
#   'track_href': 'https://api.spotify.com/v1/tracks/34gCuhDGsG4bRPIf9bb02f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34gCuhDGsG4bRPIf9bb02f',
#   'duration_ms': 281560,
#   'time_signature': 4},
#  {'danceability': 0.649,
#   'energy': 0.716,
#   'key': 8,
#   'loudness': -5.371,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.0863,
#   'instrumentalness': 2.63e-05,
#   'liveness': 0.135,
#   'valence': 0.163,
#   'tempo': 99.988,
#   'type': 'audio_features',
#   'id': '0lYBSQXN6rCTvUZvg9S0lU',
#   'uri': 'spotify:track:0lYBSQXN6rCTvUZvg9S0lU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0lYBSQXN6rCTvUZvg9S0lU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0lYBSQXN6rCTvUZvg9S0lU',
#   'duration_ms': 205947,
#   'time_signature': 4},
#  {'danceability': 0.367,
#   'energy': 0.111,
#   'key': 4,
#   'loudness': -14.084,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.978,
#   'instrumentalness': 3.97e-05,
#   'liveness': 0.0897,
#   'valence': 0.198,
#   'tempo': 82.642,
#   'type': 'audio_features',
#   'id': '43zdsphuZLzwA9k4DJhU0I',
#   'uri': 'spotify:track:43zdsphuZLzwA9k4DJhU0I',
#   'track_href': 'https://api.spotify.com/v1/tracks/43zdsphuZLzwA9k4DJhU0I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43zdsphuZLzwA9k4DJhU0I',
#   'duration_ms': 196077,
#   'time_signature': 4},
#  {'danceability': 0.449,
#   'energy': 0.585,
#   'key': 5,
#   'loudness': -6.761,
#   'mode': 1,
#   'speechiness': 0.0268,
#   'acousticness': 0.0509,
#   'instrumentalness': 8.75e-05,
#   'liveness': 0.0833,
#   'valence': 0.212,
#   'tempo': 139.631,
#   'type': 'audio_features',
#   'id': '6nek1Nin9q48AVZcWs9e9D',
#   'uri': 'spotify:track:6nek1Nin9q48AVZcWs9e9D',
#   'track_href': 'https://api.spotify.com/v1/tracks/6nek1Nin9q48AVZcWs9e9D',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nek1Nin9q48AVZcWs9e9D',
#   'duration_ms': 278719,
#   'time_signature': 4},
#  {'danceability': 0.37,
#   'energy': 0.467,
#   'key': 5,
#   'loudness': -9.013,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'acousticness': 0.0205,
#   'instrumentalness': 0.572,
#   'liveness': 0.109,
#   'valence': 0.182,
#   'tempo': 94.485,
#   'type': 'audio_features',
#   'id': '0yc6Gst2xkRu0eMLeRMGCX',
#   'uri': 'spotify:track:0yc6Gst2xkRu0eMLeRMGCX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yc6Gst2xkRu0eMLeRMGCX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yc6Gst2xkRu0eMLeRMGCX',
#   'duration_ms': 290617,
#   'time_signature': 4},
#  {'danceability': 0.635,
#   'energy': 0.841,
#   'key': 5,
#   'loudness': -5.379,
#   'mode': 1,
#   'speechiness': 0.0422,
#   'acousticness': 0.0134,
#   'instrumentalness': 0,
#   'liveness': 0.0622,
#   'valence': 0.424,
#   'tempo': 109.021,
#   'type': 'audio_features',
#   'id': '47Slg6LuqLaX0VodpSCvPt',
#   'uri': 'spotify:track:47Slg6LuqLaX0VodpSCvPt',
#   'track_href': 'https://api.spotify.com/v1/tracks/47Slg6LuqLaX0VodpSCvPt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47Slg6LuqLaX0VodpSCvPt',
#   'duration_ms': 220734,
#   'time_signature': 4},
#  {'danceability': 0.8,
#   'energy': 0.585,
#   'key': 10,
#   'loudness': -7.343,
#   'mode': 1,
#   'speechiness': 0.0924,
#   'acousticness': 0.264,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.779,
#   'tempo': 126.058,
#   'type': 'audio_features',
#   'id': '6PGoSes0D9eUDeeAafB2As',
#   'uri': 'spotify:track:6PGoSes0D9eUDeeAafB2As',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PGoSes0D9eUDeeAafB2As',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PGoSes0D9eUDeeAafB2As',
#   'duration_ms': 213400,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.779,
#   'key': 9,
#   'loudness': -4.839,
#   'mode': 1,
#   'speechiness': 0.0779,
#   'acousticness': 0.112,
#   'instrumentalness': 0.000373,
#   'liveness': 0.101,
#   'valence': 0.26,
#   'tempo': 173.799,
#   'type': 'audio_features',
#   'id': '1yvMUkIOTeUNtNWlWRgANS',
#   'uri': 'spotify:track:1yvMUkIOTeUNtNWlWRgANS',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yvMUkIOTeUNtNWlWRgANS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yvMUkIOTeUNtNWlWRgANS',
#   'duration_ms': 217747,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.866,
#   'key': 1,
#   'loudness': -3.804,
#   'mode': 1,
#   'speechiness': 0.0619,
#   'acousticness': 0.00701,
#   'instrumentalness': 0,
#   'liveness': 0.257,
#   'valence': 0.619,
#   'tempo': 128.038,
#   'type': 'audio_features',
#   'id': '4kbj5MwxO1bq9wjT5g9HaA',
#   'uri': 'spotify:track:4kbj5MwxO1bq9wjT5g9HaA',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kbj5MwxO1bq9wjT5g9HaA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kbj5MwxO1bq9wjT5g9HaA',
#   'duration_ms': 199080,
#   'time_signature': 4},
#  {'danceability': 0.856,
#   'energy': 0.609,
#   'key': 0,
#   'loudness': -7.223,
#   'mode': 1,
#   'speechiness': 0.0824,
#   'acousticness': 0.00801,
#   'instrumentalness': 8.15e-05,
#   'liveness': 0.0344,
#   'valence': 0.928,
#   'tempo': 114.988,
#   'type': 'audio_features',
#   'id': '32OlwWuMpZ6b0aN2RZOeMS',
#   'uri': 'spotify:track:32OlwWuMpZ6b0aN2RZOeMS',
#   'track_href': 'https://api.spotify.com/v1/tracks/32OlwWuMpZ6b0aN2RZOeMS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/32OlwWuMpZ6b0aN2RZOeMS',
#   'duration_ms': 269667,
# ...
#  {'danceability': 0.641,
#   'energy': 0.922,
#   'key': 2,
#   'loudness': -4.457,
#   'mode': 1,
#   'speechiness': 0.0786,
#   'acousticness': 0.0291,
#   'instrumentalness': 0,
#   'liveness': 0.0862,
#   'valence': 0.847,
#   'tempo': 146.078,
#   'type': 'audio_features',
#   'id': '3bidbhpOYeV4knp8AIu8Xn',
#   'uri': 'spotify:track:3bidbhpOYeV4knp8AIu8Xn',
#   'track_href': 'https://api.spotify.com/v1/tracks/3bidbhpOYeV4knp8AIu8Xn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bidbhpOYeV4knp8AIu8Xn',
#   'duration_ms': 258343,
#   'time_signature': 4},
#  {'danceability': 0.645,
#   'energy': 0.713,
#   'key': 6,
#   'loudness': -5.355,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.00835,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.566,
#   'tempo': 74.989,
#   'type': 'audio_features',
#   'id': '2Z8WuEywRWYTKe1NybPQEW',
#   'uri': 'spotify:track:2Z8WuEywRWYTKe1NybPQEW',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Z8WuEywRWYTKe1NybPQEW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Z8WuEywRWYTKe1NybPQEW',
#   'duration_ms': 214507,
#   'time_signature': 4},
#  {'danceability': 0.753,
#   'energy': 0.505,
#   'key': 9,
#   'loudness': -7.621,
#   'mode': 1,
#   'speechiness': 0.255,
#   'acousticness': 0.534,
#   'instrumentalness': 2.58e-06,
#   'liveness': 0.104,
#   'valence': 0.419,
#   'tempo': 91.972,
#   'type': 'audio_features',
#   'id': '0EcQcdcbQeVJn9fknj44Be',
#   'uri': 'spotify:track:0EcQcdcbQeVJn9fknj44Be',
#   'track_href': 'https://api.spotify.com/v1/tracks/0EcQcdcbQeVJn9fknj44Be',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0EcQcdcbQeVJn9fknj44Be',
#   'duration_ms': 197437,
#   'time_signature': 4},
#  {'danceability': 0.794,
#   'energy': 0.811,
#   'key': 6,
#   'loudness': -8.966,
#   'mode': 0,
#   'speechiness': 0.038,
#   'acousticness': 0.0426,
#   'instrumentalness': 1.07e-06,
#   'liveness': 0.101,
#   'valence': 0.862,
#   'tempo': 116.047,
#   'type': 'audio_features',
#   'id': '2Foc5Q5nqNiosCNqttzHof',
#   'uri': 'spotify:track:2Foc5Q5nqNiosCNqttzHof',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Foc5Q5nqNiosCNqttzHof',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Foc5Q5nqNiosCNqttzHof',
#   'duration_ms': 248413,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.522,
#   'key': 2,
#   'loudness': -4.368,
#   'mode': 1,
#   'speechiness': 0.0575,
#   'acousticness': 0.533,
#   'instrumentalness': 0,
#   'liveness': 0.0685,
#   'valence': 0.925,
#   'tempo': 89.96,
#   'type': 'audio_features',
#   'id': '0RiRZpuVRbi7oqRdSMwhQY',
#   'uri': 'spotify:track:0RiRZpuVRbi7oqRdSMwhQY',
#   'track_href': 'https://api.spotify.com/v1/tracks/0RiRZpuVRbi7oqRdSMwhQY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0RiRZpuVRbi7oqRdSMwhQY',
#   'duration_ms': 157560,
#   'time_signature': 4},
#  {'danceability': 0.748,
#   'energy': 0.788,
#   'key': 1,
#   'loudness': -7.055,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.0591,
#   'instrumentalness': 0,
#   'liveness': 0.0863,
#   'valence': 0.884,
#   'tempo': 120.076,
#   'type': 'audio_features',
#   'id': '2iuZJX9X9P0GKaE93xcPjk',
#   'uri': 'spotify:track:2iuZJX9X9P0GKaE93xcPjk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2iuZJX9X9P0GKaE93xcPjk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2iuZJX9X9P0GKaE93xcPjk',
#   'duration_ms': 235493,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.611,
#   'key': 2,
#   'loudness': -6.112,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.217,
#   'instrumentalness': 0,
#   'liveness': 0.0812,
#   'valence': 0.22,
#   'tempo': 100.0,
#   'type': 'audio_features',
#   'id': '2FY7b99s15jUprqC0M5NCT',
#   'uri': 'spotify:track:2FY7b99s15jUprqC0M5NCT',
#   'track_href': 'https://api.spotify.com/v1/tracks/2FY7b99s15jUprqC0M5NCT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FY7b99s15jUprqC0M5NCT',
#   'duration_ms': 189467,
#   'time_signature': 4},
#  {'danceability': 0.589,
#   'energy': 0.966,
#   'key': 11,
#   'loudness': -4.106,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.03,
#   'instrumentalness': 0,
#   'liveness': 0.147,
#   'valence': 0.802,
#   'tempo': 129.983,
#   'type': 'audio_features',
#   'id': '3tgZ9vmhuAY9wEoNUJskzV',
#   'uri': 'spotify:track:3tgZ9vmhuAY9wEoNUJskzV',
#   'track_href': 'https://api.spotify.com/v1/tracks/3tgZ9vmhuAY9wEoNUJskzV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tgZ9vmhuAY9wEoNUJskzV',
#   'duration_ms': 204200,
#   'time_signature': 4},
#  {'danceability': 0.759,
#   'energy': 0.548,
#   'key': 9,
#   'loudness': -6.049,
#   'mode': 0,
#   'speechiness': 0.029,
#   'acousticness': 0.0392,
#   'instrumentalness': 0,
#   'liveness': 0.0828,
#   'valence': 0.749,
#   'tempo': 116.967,
#   'type': 'audio_features',
#   'id': '6v3KW9xbzN5yKLt9YKDYA2',
#   'uri': 'spotify:track:6v3KW9xbzN5yKLt9YKDYA2',
#   'track_href': 'https://api.spotify.com/v1/tracks/6v3KW9xbzN5yKLt9YKDYA2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6v3KW9xbzN5yKLt9YKDYA2',
#   'duration_ms': 190800,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.837,
#   'key': 2,
#   'loudness': -2.718,
#   'mode': 0,
#   'speechiness': 0.142,
#   'acousticness': 0.0991,
#   'instrumentalness': 0,
#   'liveness': 0.289,
#   'valence': 0.714,
#   'tempo': 120.028,
#   'type': 'audio_features',
#   'id': '0HPD5WQqrq7wPWR7P7Dw1i',
#   'uri': 'spotify:track:0HPD5WQqrq7wPWR7P7Dw1i',
#   'track_href': 'https://api.spotify.com/v1/tracks/0HPD5WQqrq7wPWR7P7Dw1i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HPD5WQqrq7wPWR7P7Dw1i',
#   'duration_ms': 199693,
#   'time_signature': 4},
#  {'danceability': 0.697,
#   'energy': 0.683,
#   'key': 1,
#   'loudness': -2.881,
#   'mode': 0,
#   'speechiness': 0.117,
#   'acousticness': 0.0372,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.603,
#   'tempo': 96.133,
#   'type': 'audio_features',
#   'id': '2BgEsaKNfHUdlh97KmvFyo',
#   'uri': 'spotify:track:2BgEsaKNfHUdlh97KmvFyo',
#   'track_href': 'https://api.spotify.com/v1/tracks/2BgEsaKNfHUdlh97KmvFyo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BgEsaKNfHUdlh97KmvFyo',
#   'duration_ms': 186987,
#   'time_signature': 4},
#  {'danceability': 0.579,
#   'energy': 0.904,
#   'key': 5,
#   'loudness': -2.729,
#   'mode': 1,
#   'speechiness': 0.0618,
#   'acousticness': 0.193,
#   'instrumentalness': 0,
#   'liveness': 0.064,
#   'valence': 0.681,
#   'tempo': 82.014,
#   'type': 'audio_features',
#   'id': '1rqqCSm0Qe4I9rUvWncaom',
#   'uri': 'spotify:track:1rqqCSm0Qe4I9rUvWncaom',
#   'track_href': 'https://api.spotify.com/v1/tracks/1rqqCSm0Qe4I9rUvWncaom',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rqqCSm0Qe4I9rUvWncaom',
#   'duration_ms': 190947,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.547,
#   'key': 2,
#   'loudness': -7.273,
#   'mode': 1,
#   'speechiness': 0.0489,
#   'acousticness': 0.346,
#   'instrumentalness': 0.000302,
#   'liveness': 0.132,
#   'valence': 0.441,
#   'tempo': 95.002,
#   'type': 'audio_features',
#   'id': '1mKXFLRA179hdOWQBwUk9e',
#   'uri': 'spotify:track:1mKXFLRA179hdOWQBwUk9e',
#   'track_href': 'https://api.spotify.com/v1/tracks/1mKXFLRA179hdOWQBwUk9e',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mKXFLRA179hdOWQBwUk9e',
#   'duration_ms': 242733,
#   'time_signature': 4},
#  {'danceability': 0.829,
#   'energy': 0.539,
#   'key': 11,
#   'loudness': -7.359,
#   'mode': 0,
#   'speechiness': 0.208,
#   'acousticness': 0.136,
#   'instrumentalness': 1.78e-06,
#   'liveness': 0.103,
#   'valence': 0.388,
#   'tempo': 99.96,
#   'type': 'audio_features',
#   'id': '7xQAfvXzm3AkraOtGPWIZg',
#   'uri': 'spotify:track:7xQAfvXzm3AkraOtGPWIZg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xQAfvXzm3AkraOtGPWIZg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xQAfvXzm3AkraOtGPWIZg',
#   'duration_ms': 149547,
#   'time_signature': 4},
#  {'danceability': 0.764,
#   'energy': 0.705,
#   'key': 3,
#   'loudness': -5.279,
#   'mode': 0,
#   'speechiness': 0.0278,
#   'acousticness': 0.0371,
#   'instrumentalness': 1.94e-05,
#   'liveness': 0.0943,
#   'valence': 0.672,
#   'tempo': 101.003,
#   'type': 'audio_features',
#   'id': '0y60itmpH0aPKsFiGxmtnh',
#   'uri': 'spotify:track:0y60itmpH0aPKsFiGxmtnh',
#   'track_href': 'https://api.spotify.com/v1/tracks/0y60itmpH0aPKsFiGxmtnh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0y60itmpH0aPKsFiGxmtnh',
#   'duration_ms': 196520,
#   'time_signature': 4},
#  {'danceability': 0.672,
#   'energy': 0.655,
#   'key': 10,
#   'loudness': -5.021,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.0362,
#   'instrumentalness': 0,
#   'liveness': 0.117,
#   'valence': 0.556,
#   'tempo': 134.945,
#   'type': 'audio_features',
#   'id': '6Qn5zhYkTa37e91HC1D7lb',
#   'uri': 'spotify:track:6Qn5zhYkTa37e91HC1D7lb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Qn5zhYkTa37e91HC1D7lb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Qn5zhYkTa37e91HC1D7lb',
#   'duration_ms': 201240,
#   'time_signature': 4},
#  {'danceability': 0.773,
#   'energy': 0.819,
#   'key': 0,
#   'loudness': -5.946,
#   'mode': 0,
#   'speechiness': 0.118,
#   'acousticness': 0.428,
#   'instrumentalness': 0,
#   'liveness': 0.0679,
#   'valence': 0.585,
#   'tempo': 92.987,
#   'type': 'audio_features',
#   'id': '3dhjNA0jGA8vHBQ1VdD6vV',
#   'uri': 'spotify:track:3dhjNA0jGA8vHBQ1VdD6vV',
#   'track_href': 'https://api.spotify.com/v1/tracks/3dhjNA0jGA8vHBQ1VdD6vV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dhjNA0jGA8vHBQ1VdD6vV',
#   'duration_ms': 269187,
#   'time_signature': 4},
#  {'danceability': 0.774,
#   'energy': 0.753,
#   'key': 4,
#   'loudness': -5.446,
#   'mode': 0,
#   'speechiness': 0.0517,
#   'acousticness': 0.152,
#   'instrumentalness': 0,
#   'liveness': 0.0371,
#   'valence': 0.896,
#   'tempo': 119.002,
#   'type': 'audio_features',
#   'id': '76hfruVvmfQbw0eYn1nmeC',
#   'uri': 'spotify:track:76hfruVvmfQbw0eYn1nmeC',
#   'track_href': 'https://api.spotify.com/v1/tracks/76hfruVvmfQbw0eYn1nmeC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/76hfruVvmfQbw0eYn1nmeC',
#   'duration_ms': 219147,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.859,
#   'key': 5,
#   'loudness': -5.237,
#   'mode': 0,
#   'speechiness': 0.137,
#   'acousticness': 0.0401,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.535,
#   'tempo': 65.043,
#   'type': 'audio_features',
#   'id': '6epn3r7S14KUqlReYr77hA',
#   'uri': 'spotify:track:6epn3r7S14KUqlReYr77hA',
#   'track_href': 'https://api.spotify.com/v1/tracks/6epn3r7S14KUqlReYr77hA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6epn3r7S14KUqlReYr77hA',
#   'duration_ms': 214240,
#   'time_signature': 4},
#  {'danceability': 0.612,
#   'energy': 0.84,
#   'key': 11,
#   'loudness': -3.145,
#   'mode': 0,
#   'speechiness': 0.0509,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.438,
#   'tempo': 129.042,
#   'type': 'audio_features',
#   'id': '2V65y3PX4DkRhy1djlxd9p',
#   'uri': 'spotify:track:2V65y3PX4DkRhy1djlxd9p',
#   'track_href': 'https://api.spotify.com/v1/tracks/2V65y3PX4DkRhy1djlxd9p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2V65y3PX4DkRhy1djlxd9p',
#   'duration_ms': 212862,
#   'time_signature': 4},
#  {'danceability': 0.72,
#   'energy': 0.791,
#   'key': 1,
#   'loudness': -4.689,
#   'mode': 1,
#   'speechiness': 0.124,
#   'acousticness': 0.0384,
#   'instrumentalness': 0,
#   'liveness': 0.157,
#   'valence': 0.756,
#   'tempo': 102.071,
#   'type': 'audio_features',
#   'id': '6FE2iI43OZnszFLuLtvvmg',
#   'uri': 'spotify:track:6FE2iI43OZnszFLuLtvvmg',
#   'track_href': 'https://api.spotify.com/v1/tracks/6FE2iI43OZnszFLuLtvvmg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6FE2iI43OZnszFLuLtvvmg',
#   'duration_ms': 175427,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.856,
#   'key': 4,
#   'loudness': -3.556,
#   'mode': 0,
#   'speechiness': 0.0346,
#   'acousticness': 0.0211,
#   'instrumentalness': 0.0178,
#   'liveness': 0.141,
#   'valence': 0.743,
#   'tempo': 127.949,
#   'type': 'audio_features',
#   'id': '6YUTL4dYpB9xZO5qExPf05',
#   'uri': 'spotify:track:6YUTL4dYpB9xZO5qExPf05',
#   'track_href': 'https://api.spotify.com/v1/tracks/6YUTL4dYpB9xZO5qExPf05',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YUTL4dYpB9xZO5qExPf05',
#   'duration_ms': 222533,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.519,
#   'key': 4,
#   'loudness': -5.88,
#   'mode': 0,
#   'speechiness': 0.0409,
#   'acousticness': 0.109,
#   'instrumentalness': 0,
#   'liveness': 0.454,
#   'valence': 0.168,
#   'tempo': 133.99,
#   'type': 'audio_features',
#   'id': '23L5CiUhw2jV1OIMwthR3S',
#   'uri': 'spotify:track:23L5CiUhw2jV1OIMwthR3S',
#   'track_href': 'https://api.spotify.com/v1/tracks/23L5CiUhw2jV1OIMwthR3S',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23L5CiUhw2jV1OIMwthR3S',
#   'duration_ms': 195707,
#   'time_signature': 4},
#  {'danceability': 0.603,
#   'energy': 0.67,
#   'key': 2,
#   'loudness': -3.882,
#   'mode': 0,
#   'speechiness': 0.0249,
#   'acousticness': 0.00408,
#   'instrumentalness': 1.68e-06,
#   'liveness': 0.112,
#   'valence': 0.446,
#   'tempo': 107.993,
#   'type': 'audio_features',
#   'id': '3di5hcvxxciiqwMH1jarhY',
#   'uri': 'spotify:track:3di5hcvxxciiqwMH1jarhY',
#   'track_href': 'https://api.spotify.com/v1/tracks/3di5hcvxxciiqwMH1jarhY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3di5hcvxxciiqwMH1jarhY',
#   'duration_ms': 242974,
#   'time_signature': 4},
#  {'danceability': 0.855,
#   'energy': 0.954,
#   'key': 0,
#   'loudness': -1.19,
#   'mode': 0,
#   'speechiness': 0.264,
#   'acousticness': 0.529,
#   'instrumentalness': 0,
#   'liveness': 0.205,
#   'valence': 0.668,
#   'tempo': 114.635,
#   'type': 'audio_features',
#   'id': '7Ie9W94M7OjPoZVV216Xus',
#   'uri': 'spotify:track:7Ie9W94M7OjPoZVV216Xus',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Ie9W94M7OjPoZVV216Xus',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Ie9W94M7OjPoZVV216Xus',
#   'duration_ms': 248133,
#   'time_signature': 5},
#  {'danceability': 0.52,
#   'energy': 0.761,
#   'key': 4,
#   'loudness': -3.093,
#   'mode': 1,
#   'speechiness': 0.0853,
#   'acousticness': 0.256,
#   'instrumentalness': 4.96e-06,
#   'liveness': 0.17,
#   'valence': 0.286,
#   'tempo': 141.971,
#   'type': 'audio_features',
#   'id': '7vGuf3Y35N4wmASOKLUVVU',
#   'uri': 'spotify:track:7vGuf3Y35N4wmASOKLUVVU',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vGuf3Y35N4wmASOKLUVVU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vGuf3Y35N4wmASOKLUVVU',
#   'duration_ms': 180823,
#   'time_signature': 4},
#  {'danceability': 0.188,
#   'energy': 0.411,
#   'key': 0,
#   'loudness': -9.733,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.174,
#   'instrumentalness': 0.153,
#   'liveness': 0.0843,
#   'valence': 0.159,
#   'tempo': 187.376,
#   'type': 'audio_features',
#   'id': '0NlGoUyOJSuSHmngoibVAs',
#   'uri': 'spotify:track:0NlGoUyOJSuSHmngoibVAs',
#   'track_href': 'https://api.spotify.com/v1/tracks/0NlGoUyOJSuSHmngoibVAs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NlGoUyOJSuSHmngoibVAs',
#   'duration_ms': 305747,
#   'time_signature': 3},
#  {'danceability': 0.647,
#   'energy': 0.822,
#   'key': 5,
#   'loudness': -4.662,
#   'mode': 0,
#   'speechiness': 0.183,
#   'acousticness': 0.219,
#   'instrumentalness': 0,
#   'liveness': 0.0908,
#   'valence': 0.962,
#   'tempo': 160.019,
#   'type': 'audio_features',
#   'id': '60nZcImufyMA1MKQY3dcCH',
#   'uri': 'spotify:track:60nZcImufyMA1MKQY3dcCH',
#   'track_href': 'https://api.spotify.com/v1/tracks/60nZcImufyMA1MKQY3dcCH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60nZcImufyMA1MKQY3dcCH',
#   'duration_ms': 232720,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.794,
#   'key': 7,
#   'loudness': -5.844,
#   'mode': 0,
#   'speechiness': 0.0671,
#   'acousticness': 0.00987,
#   'instrumentalness': 1.36e-06,
#   'liveness': 0.388,
#   'valence': 0.244,
#   'tempo': 114.066,
#   'type': 'audio_features',
#   'id': '27rdGxbavYJeBphck5MZAF',
#   'uri': 'spotify:track:27rdGxbavYJeBphck5MZAF',
#   'track_href': 'https://api.spotify.com/v1/tracks/27rdGxbavYJeBphck5MZAF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27rdGxbavYJeBphck5MZAF',
#   'duration_ms': 217467,
#   'time_signature': 4}]

# %%
# Check where to find artist names
print(tracks[0]['track']['artists'][0]['name'])
# Out:
# Rihanna

# %%
# define a function to get artists from tracks
def get_tracks_artists(username, playlist_id):
    tracks = get_playlist_tracks(username, playlist_id)
    artists = []
    for i in range(0, len(tracks)):
        artists.append(tracks[i]['track']['artists'][i]['name'])
    return artists

# %%
#get artists from tracks and include it to the dataframe
artists = get_playlist_tracks(username, playlist_id)

# %%
top2010s['artist'] = artists
# Out:
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_13644\3852325598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top2010s['artist'] = artists

# %%
top2010s
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.735   0.766    -4.485       0.0383       0.02500
# 1           0.758   0.871    -6.408       0.1470       0.00620
# 2           0.532   0.783    -5.697       0.0523       0.00380
# 3           0.669   0.832    -5.721       0.0682       0.01060
# 4           0.654   0.760    -3.669       0.0450       0.07970
# ..            ...     ...       ...          ...           ...
# 145         0.855   0.954    -1.190       0.2640       0.52900
# 146         0.520   0.761    -3.093       0.0853       0.25600
# 147         0.188   0.411    -9.733       0.0484       0.17400
# 148         0.647   0.822    -4.662       0.1830       0.21900
# 149         0.601   0.794    -5.844       0.0671       0.00987
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.001380    0.1080    0.600  127.985  0U10zFw4GlBacOy9VDGfGL
# 1            0.000000    0.0663    0.753  126.994  6bNB5gxFX6Q87DbQWb8OWZ
# 2            0.001200    0.1610    0.643  124.080  0nrRP2bk19rLc0orkWPQk2
# 3            0.000000    0.0968    0.700  113.035  1WkMMavIMc4JZ8cfMmxHkI
# 4            0.000000    0.2990    0.410   99.945  09CtPGIpYB4BrO8qb1RGsF
# ..                ...       ...      ...      ...                     ...
# 145          0.000000    0.2050    0.668  114.635  7Ie9W94M7OjPoZVV216Xus
# 146          0.000005    0.1700    0.286  141.971  7vGuf3Y35N4wmASOKLUVVU
# 147          0.153000    0.0843    0.159  187.376  0NlGoUyOJSuSHmngoibVAs
# 148          0.000000    0.0908    0.962  160.019  60nZcImufyMA1MKQY3dcCH
# 149          0.000001    0.3880    0.244  114.066  27rdGxbavYJeBphck5MZAF
#
#      duration_ms                                             artist  \
# 0         215227  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 1         202627  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 2         247427  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 3         237547  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 4         200787  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# ..           ...                                                ...
# 145       248133  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 146       180823  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 147       305747  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 148       232720  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 149       217467  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
#
#                                                   name  \
# 0                                        We Found Love
# 1    Waka Waka (This Time for Africa) [The Official...
# 2                                           Wake Me Up
# 3    CAN'T STOP THE FEELING! (from DreamWorks Anima...
# 4                                                Sorry
# ..                                                 ...
# 145                                         Not Afraid
# 146                                            Silence
# 147                                         All I Want
# 148                     Happy - From "Despicable Me 2"
# 149    Nothing Breaks Like a Heart (feat. Miley Cyrus)
#
#                                                  album  popularity
# 0                                       Talk That Talk          75
# 1    Listen Up! The Official 2010 FIFA World Cup Album          79
# 2                                                 True          82
# 3          TROLLS (Original Motion Picture Soundtrack)          69
# 4                                     Purpose (Deluxe)          78
# ..                                                 ...         ...
# 145                                           Recovery          77
# 146                                            Silence          77
# 147              In A Perfect World (Expanded Edition)          77
# 148                                            G I R L          77
# 149    Nothing Breaks Like a Heart (feat. Miley Cyrus)          77
#
# [150 rows x 15 columns]

# %%
# check where to find track names
print(tracks[0]['track']['name'])
# Out:
# We Found Love

# %%
# define a function to get track names
def get_tracks_names(username, playlist_id):
    tracks = get_playlist_tracks(username, playlist_id)
    track_names = []
    for item in range(0, len(tracks)):
        track_names.append(tracks[item]['track']['name'])
    return track_names

# %%
#get get track names and include it to the dataframe
track_names = get_tracks_names(username, playlist_id)
top2010s['name'] = track_names
# Out:
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_13644\1200408631.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top2010s['name'] = track_names

# %%
# check where to get album names
print(tracks[0]['track']['album']['name'])
# Out:
# Talk That Talk

# %%
# define a function to get track names
def get_tracks_albums(username, playlist_id):
    tracks = get_playlist_tracks(username, playlist_id)
    albums = []
    for item in range(0, len(tracks)):
        albums.append(tracks[item]['track']['album']['name'])
    return albums

# %%
#get get track names and include it to the dataframe
albums = get_tracks_albums(username, playlist_id)
top2010s['album'] = albums
# Out:
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_13644\1006485094.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top2010s['album'] = albums

# %%
# check where to get the popularity of tracks
print(tracks[0]['track']['popularity'])
# Out:
# 75

# %%
# define a function to get track names
def get_tracks_popularity(username, playlist_id):
    tracks = get_playlist_tracks(username, playlist_id)
    popularity_li = []
    for item in range(0, len(tracks)):
        popularity_li.append(tracks[item]['track']['popularity'])
    return popularity_li

# %%
#get get track popularity rate and include it to the dataframe
popularity_li = get_tracks_popularity(username, playlist_id)
top2010s['popularity'] = popularity_li
# Out:
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_13644\480096816.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top2010s['popularity'] = popularity_li

# %%
top2010s
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.735   0.766    -4.485       0.0383       0.02500
# 1           0.758   0.871    -6.408       0.1470       0.00620
# 2           0.532   0.783    -5.697       0.0523       0.00380
# 3           0.669   0.832    -5.721       0.0682       0.01060
# 4           0.654   0.760    -3.669       0.0450       0.07970
# ..            ...     ...       ...          ...           ...
# 145         0.855   0.954    -1.190       0.2640       0.52900
# 146         0.520   0.761    -3.093       0.0853       0.25600
# 147         0.188   0.411    -9.733       0.0484       0.17400
# 148         0.647   0.822    -4.662       0.1830       0.21900
# 149         0.601   0.794    -5.844       0.0671       0.00987
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.001380    0.1080    0.600  127.985  0U10zFw4GlBacOy9VDGfGL
# 1            0.000000    0.0663    0.753  126.994  6bNB5gxFX6Q87DbQWb8OWZ
# 2            0.001200    0.1610    0.643  124.080  0nrRP2bk19rLc0orkWPQk2
# 3            0.000000    0.0968    0.700  113.035  1WkMMavIMc4JZ8cfMmxHkI
# 4            0.000000    0.2990    0.410   99.945  09CtPGIpYB4BrO8qb1RGsF
# ..                ...       ...      ...      ...                     ...
# 145          0.000000    0.2050    0.668  114.635  7Ie9W94M7OjPoZVV216Xus
# 146          0.000005    0.1700    0.286  141.971  7vGuf3Y35N4wmASOKLUVVU
# 147          0.153000    0.0843    0.159  187.376  0NlGoUyOJSuSHmngoibVAs
# 148          0.000000    0.0908    0.962  160.019  60nZcImufyMA1MKQY3dcCH
# 149          0.000001    0.3880    0.244  114.066  27rdGxbavYJeBphck5MZAF
#
#      duration_ms                                             artist  \
# 0         215227  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 1         202627  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 2         247427  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 3         237547  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 4         200787  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# ..           ...                                                ...
# 145       248133  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 146       180823  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 147       305747  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 148       232720  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
# 149       217467  {'added_at': '2022-10-09T00:00:00Z', 'added_by...
#
#                                                   name  \
# 0                                        We Found Love
# 1    Waka Waka (This Time for Africa) [The Official...
# 2                                           Wake Me Up
# 3    CAN'T STOP THE FEELING! (from DreamWorks Anima...
# 4                                                Sorry
# ..                                                 ...
# 145                                         Not Afraid
# 146                                            Silence
# 147                                         All I Want
# 148                     Happy - From "Despicable Me 2"
# 149    Nothing Breaks Like a Heart (feat. Miley Cyrus)
#
#                                                  album  popularity
# 0                                       Talk That Talk          75
# 1    Listen Up! The Official 2010 FIFA World Cup Album          79
# 2                                                 True          82
# 3          TROLLS (Original Motion Picture Soundtrack)          69
# 4                                     Purpose (Deluxe)          78
# ..                                                 ...         ...
# 145                                           Recovery          77
# 146                                            Silence          77
# 147              In A Perfect World (Expanded Edition)          77
# 148                                            G I R L          77
# 149    Nothing Breaks Like a Heart (feat. Miley Cyrus)          77
#
# [150 rows x 15 columns]
