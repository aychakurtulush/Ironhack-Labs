# %% [markdown]
# The purpose of this notebook is I would like to introduce my friend and his holiday preferences.

# %%
name = str(input("Please write your name: ")) #this function is for getting input from the user for his name
# Out:
# Please write your name: Danilo

# %%
print("His name is: " + name) #this function is for printing the user's response to the previous line
# Out:
# His name is: Danilo

# %% [markdown]
# ![pexels-photo-220453.webp](attachment:pexels-photo-220453.webp)

# %% [markdown]
# His holiday preference is *Switzerland*

# %% [markdown]
# ![bern-switzerland-shutterstock_1845136612.jpg_ecb4c93750.jpg](attachment:bern-switzerland-shutterstock_1845136612.jpg_ecb4c93750.jpg)

# %% [markdown]
# -Visit Museum
# -Snowboarding
# -Tasting Chocolade
